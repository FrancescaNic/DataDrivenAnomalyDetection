# %%
import pandas as pd
from matplotlib import pyplot as plt
import statistics

# %% [markdown]
# # Data Exploration

# %%
d1 = pd.read_csv('QUALITY_Vc250_F910_ap075.csv', delimiter = ';', decimal=',', usecols = ['Time', '     A1', '     A2', '     A3'])
d1=d1.rename(columns={"     A1": "A1", "     A2": "A2", "     A3": "A3"})
d1
# Out:
#             Time     A1    A2    A3
# 0       0.000000  10.00 -0.37  0.23
# 1       0.000309   9.97 -0.37  0.23
# 2       0.000617   9.97 -0.34  0.20
# 3       0.000926   9.97 -0.37  0.20
# 4       0.001234  10.00 -0.34  0.26
# ...          ...    ...   ...   ...
# 51963  16.037963   9.97 -0.34  0.23
# 51964  16.038272   9.97 -0.37  0.23
# 51965  16.038580   9.97 -0.37  0.26
# 51966  16.038889   9.97 -0.40  0.29
# 51967  16.039197  10.00 -0.40  0.29
#
# [51968 rows x 4 columns]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
fig.suptitle('External ap 0.75 mm')
ax1.plot(d1['Time'], d1['A1'])
ax1.set(xlabel='Time', ylabel='A1')
ax2.plot(d1['Time'], d1['A2'])
ax2.set(xlabel='Time', ylabel='A2')
ax3.plot(d1['Time'], d1['A3'])
ax3.set(xlabel='Time', ylabel='A3')
plt.savefig('External ap 0.75 mm.png')

# %% [markdown]
# # Cleaning

# %%
# Zoomed trials to define cleaning interval
plt.plot(d1['A1'][16200:30680])
plt.xlabel('Time')
plt.ylabel('A1')
plt.title('Zoomed trials to define cleaning interval')
plt.show()

# %%
d1_clean = d1[16200:30680]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
fig.suptitle('External ap 0.75 mm Cleaned')
ax1.plot(d1_clean['Time'], d1_clean['A1'])
ax1.set(xlabel='Time', ylabel='A1')
ax2.plot(d1_clean['Time'], d1_clean['A2'])
ax2.set(xlabel='Time', ylabel='A2')
ax3.plot(d1_clean['Time'], d1_clean['A3'])
ax3.set(xlabel='Time', ylabel='A3')
plt.savefig('External ap 0.75 mm cleaned.png')

# %%
d1_clean.to_csv('QUALITY_Vc250_F910_ap075_cleaned.csv')
